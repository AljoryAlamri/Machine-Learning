# %%
name = "Aljory"
age = 24
height = 152
is_student = True
print(name)
print(age)
print(height)
print(is_student)
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# Aljory
# 24
# 152
# True
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>

# %%
a = 2
b = 8
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor division:", a // b)
print("Remainder:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 10
# Subtraction: -6
# Multiplication: 16
# Division: 0.25
# Floor division: 0
# Remainder: 2
# Power: 256

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print("Hello", name)
print("Next year you will be", age + 1)
# Out:
# Enter your name: Aljory
# Enter your age: 24
# Hello Aljory
# Next year you will be 25

# %%
mark = float(input("Enter your mark: "))
if mark >= 60:
 print("Pass")
else:
 print("Fail")
# Out:
# Enter your mark: 96
# Pass

# %%
marks = [90, 77, 71, 88, 89]
print("Marks:", marks)
print("First mark:", marks[0])
print("Third mark:", marks[2])
print("Number of marks:", len(marks))
print("Total:", sum(marks))
print("Highest:", max(marks))
print("Lowest:", min(marks))
print("Average:", sum(marks) / len(marks))
# Out:
# Marks: [90, 77, 71, 88, 89]
# First mark: 90
# Third mark: 71
# Number of marks: 5
# Total: 415
# Highest: 90
# Lowest: 71
# Average: 83.0

# %%
temperature = [27.4, 22.1, 29.3, 24.0, 21.8]
print("Number of observations:", len(temperature))
print("Average temperature:", sum(temperature) / len(temperature))
print("Minimum temperature:", min(temperature))
print("Maximum temperature:", max(temperature))
# Out:
# Number of observations: 5
# Average temperature: 24.919999999999998
# Minimum temperature: 21.8
# Maximum temperature: 29.3

# %%
study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [51, 58, 60, 66, 72, 80, 90]
for i in range(len(study_hours)):
 print("Study hours:", study_hours[i], "Marks:", marks[i])
# Out:
# Study hours: 1 Marks: 51
# Study hours: 2 Marks: 58
# Study hours: 3 Marks: 60
# Study hours: 4 Marks: 66
# Study hours: 5 Marks: 72
# Study hours: 6 Marks: 80
# Study hours: 7 Marks: 90

# %%
marks = [50, 55, 60, 65, 72, 80, 88]
for mark in marks:
 if mark >= 60:
  print(mark, "Pass")
else:
 print(mark, "Fail")
# Out:
# 60 Pass
# 65 Pass
# 72 Pass
# 80 Pass
# 88 Pass
# 88 Fail

# %%
# Dataset
study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [50, 55, 60, 65, 72, 80, 88]

# 1. Number of samples
print("Number of samples:", len(marks))

# 2. Average study hours
print("Average study hours:", sum(study_hours) / len(study_hours))

# 3. Average marks
print("Average marks:", sum(marks) / len(marks))

# 4. Highest and lowest marks
print("Highest mark:", max(marks))
print("Lowest mark:", min(marks))

# 5. Display each sample
for i in range(len(study_hours)):
    print("Study hours:", study_hours[i], "Mark:", marks[i])

# 6. Pass/Fail
for i in range(len(marks)):
    if marks[i] >= 60:
        print("Mark:", marks[i], "Pass")
    else:
        print("Mark:", marks[i], "Fail")

# 7. Count the number of passes
passes = 0

for mark in marks:
    if mark >= 60:
        passes += 1

print("Number of passes:", passes)
# Out:
# Number of samples: 7
# Average study hours: 4.0
# Average marks: 67.14285714285714
# Highest mark: 88
# Lowest mark: 50
# Study hours: 1 Mark: 50
# Study hours: 2 Mark: 55
# Study hours: 3 Mark: 60
# Study hours: 4 Mark: 65
# Study hours: 5 Mark: 72
# Study hours: 6 Mark: 80
# Study hours: 7 Mark: 88
# Mark: 50 Fail
# Mark: 55 Fail
# Mark: 60 Pass
# Mark: 65 Pass
# Mark: 72 Pass
# Mark: 80 Pass
# Mark: 88 Pass
# Number of passes: 5
